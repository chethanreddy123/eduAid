# %%
import requests
import time

# URL of the backend server
backend_url = "https://eduaid-backend-693f.onrender.com/docs"

# Function to send a GET request to the backend server
def ping_backend():
    try:
        response = requests.get(backend_url)
        if response.status_code == 200:
            print(f"Backend server pinged successfully at {time.ctime()}")
        else:
            print(f"Failed to ping the backend server. Status code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Main loop to ping the backend server every one minute
while True:
    ping_backend()
    time.sleep(60)  # Sleep for 60 seconds
# Out:
# Backend server pinged successfully at Sat Feb  3 19:26:06 2024
# Backend server pinged successfully at Sat Feb  3 19:27:07 2024
# Backend server pinged successfully at Sat Feb  3 19:28:07 2024
# Backend server pinged successfully at Sat Feb  3 19:29:08 2024
# Backend server pinged successfully at Sat Feb  3 19:30:08 2024
# Backend server pinged successfully at Sat Feb  3 19:31:09 2024
# Backend server pinged successfully at Sat Feb  3 19:32:09 2024
# Backend server pinged successfully at Sat Feb  3 19:33:10 2024
# Backend server pinged successfully at Sat Feb  3 19:34:11 2024
# Backend server pinged successfully at Sat Feb  3 19:35:11 2024
# Backend server pinged successfully at Sat Feb  3 19:36:12 2024
# Backend server pinged successfully at Sat Feb  3 19:37:12 2024
# Backend server pinged successfully at Sat Feb  3 19:38:13 2024
# Backend server pinged successfully at Sat Feb  3 19:39:13 2024
# Backend server pinged successfully at Sat Feb  3 19:40:14 2024
# ...
